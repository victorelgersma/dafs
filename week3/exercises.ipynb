# %% [markdown]
# exercises from:
# https://jpvdp.github.io/NetworkIsLife/DAFS_prog_week_3_R.html

# %%
def multiples():
    for i in range(1,50):
        if (i % 3 ==0 | i %5 ==0):
            print(i)

multiples
