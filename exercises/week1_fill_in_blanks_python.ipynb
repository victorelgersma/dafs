# %% [markdown]
# # Week 1 – Fill‑in‑the‑Blank Exercises (Python, Jupyter)
#
# Replace every `___` with the correct code/value. Run a cell after you edit it to see if you pass the check.
#
# **Tip:** Run a cell with Shift+Enter.

# %%
# Helper utilities used by the exercises
def check(ok, msg_ok="✓ Correct", msg_fail="✗ Not yet — re-check"):
    print(msg_ok if ok else msg_fail)

def line():
    print("\n" + "-" * 56 + "\n")

# %% [markdown]
# ## Exercise 1 — Print a greeting
# **Goal:** Use `print()` to show text.
#
# _Expected output:_ `Hello, world!`

# %%
# Replace ___ with the correct function argument
print("Hello, World!")  # should show: Hello, world!

# Visual check
print("If you see 'Hello, world!' above, you did it.")
# Out:
# Hello, World!
# If you see 'Hello, world!' above, you did it.

# %% [markdown]
# ## Exercise 2 — Variables and arithmetic
# **Goal:** Create `a` and `b`, multiply them, print the result (**42**).

# %%
a = ___     
b = ___ 
prod_ab = ___ * ___
print(prod_ab)

check(prod_ab == 42)

# %% [markdown]
# ## Exercise 3 — Text vs number
# **Goal:** Understand difference between `int` and `str`.

# %%
# Create a numeric
x = ___        
# Create a textual variable
y = ___      

# Check that the variable is of the correct type
# (We've used this function in the exercices on NetworkIsLife
______(x)
______(y)

# %% [markdown]
# ## Exercise 4 — Concatenate text
# **Goal:** Build strings with space and with an underscore.

# %%
# We have a first and last name, we want to combine them into one string
# 1) We want a string in which the names are separeted with a space
# 2) We want a string in which the names are separeted with a "_"

first = "Freya"
last  = "Crescent"
 
full1 = ___ + ___ + ___          
full2 = ___ + ___ + ___
print(full1)
print(full2)

check(full1 == "Freya Crescent" and full2 == "Freya_Crescent")

# %% [markdown]
# ## Exercise 5 — Using a function (`sqrt` + `round`)
# **Goal:** Compute square root of 50 and round to 2 decimals.
# You will have to find the name of the functions to compute the square root and to round the number up online.

# %%
# Start by installing the math package
# Load the math package
____ math
n = 50
r = math.____(___)                 
rounded = ____(___, 2)          
print(rounded)

check(abs(rounded - 7.07) < 1e-9)

# %% [markdown]
# ## Exercise 6 — Minutes to hours:minutes
# **Goal:** Use integer division `//` and modulo `%`.
# **Goal:** Transform a number of minutes into a string tahat gives the number of hours and minutes (i.e 4 hours 15 minutes instead of 255 minutes). You will need an operator for the division and to compute the remainder (also called modulo).  Find these functions online.

# %%
minutes = 135
hours = minutes __ 135   
left  = minutes _ 135  

msg = f"{hours} hour(s) and {left} minute(s)"
print(msg)

check(hours == 2 and left == 15)

# %% [markdown]
# ## Exercise 7 — Logic operators
# **Goal:** Create a script that checks the age to determine if someone is eligible for a student discount
# The discount is valid if the person is either a student or age <= 18

# %%
age = 19
student = True

is_adult = ___ >= ___               
discount_eligible = student ___ age <= 18   

print(is_adult)
print(discount_eligible)

check(is_adult is True and discount_eligible in (True, False))

# %% [markdown]
# ## Exercise 8 — Count characters
# **Goal:** Find how many characters a string has. Find the function to count the number of characters online. HINT: the function is 3 characters long.

# %%
title = "Data Analytics"
k = ___(title)                
msg2 = "The title has " + ___ + " characters."  # use str(k)
print(msg2)

check(k == 15 and "15" in msg2)

# %% [markdown]
# ## Exercise 9 — Import a module and use a function
# **Goal:** Use `math` functions after importing the module.

# %%
line()
# Hint: you've already imported math above, but do it again here for practice.
import ___
root_144 = ___.sqrt(___)    # sqrt of 144
print(root_144)

check(root_144 == 12.0)
